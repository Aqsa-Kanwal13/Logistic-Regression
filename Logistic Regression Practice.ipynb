# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv("weatherAUS.csv")

# %%
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity3pm  \
# 0            NaN           W           44.0          W  ...        22.0
# 1            NaN         WNW           44.0        NNW  ...        25.0
# 2            NaN         WSW           46.0          W  ...        30.0
# 3            NaN          NE           24.0         SE  ...        16.0
# 4            NaN           W           41.0        ENE  ...        33.0
# ...          ...         ...            ...        ...  ...         ...
# 142188       NaN           E           31.0        ESE  ...        27.0
# 142189       NaN           E           31.0         SE  ...        24.0
# 142190       NaN         NNW           22.0         SE  ...        21.0
# 142191       NaN           N           37.0         SE  ...        24.0
# 142192       NaN          SE           28.0        SSE  ...        24.0
#
#         Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  \
# 0            1007.7       1007.1       8.0       NaN     16.9     21.8
# 1            1010.6       1007.8       NaN       NaN     17.2     24.3
# 2            1007.6       1008.7       NaN       2.0     21.0     23.2
# 3            1017.6       1012.8       NaN       NaN     18.1     26.5
# 4            1010.8       1006.0       7.0       8.0     17.8     29.7
# ...             ...          ...       ...       ...      ...      ...
# 142188       1024.7       1021.2       NaN       NaN      9.4     20.9
# 142189       1024.6       1020.3       NaN       NaN     10.1     22.4
# 142190       1023.5       1019.1       NaN       NaN     10.9     24.5
# 142191       1021.0       1016.8       NaN       NaN     12.5     26.1
# 142192       1019.4       1016.5       3.0       2.0     15.1     26.0
#
#         RainToday  RISK_MM  RainTomorrow
# 0              No      0.0            No
# 1              No      0.0            No
# 2              No      0.0            No
# 3              No      1.0            No
# 4              No      0.2            No
# ...           ...      ...           ...
# 142188         No      0.0            No
# 142189         No      0.0            No
# 142190         No      0.0            No
# 142191         No      0.0            No
# 142192         No      0.0            No
#
# [142193 rows x 24 columns]

# %%
df.shape
# Out:
# (142193, 24)

# %%
df.columns
# Out:
# Index(['Date', 'Location', 'MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation',
#        'Sunshine', 'WindGustDir', 'WindGustSpeed', 'WindDir9am', 'WindDir3pm',
#        'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm',
#        'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am',
#        'Temp3pm', 'RainToday', 'RISK_MM', 'RainTomorrow'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 24 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           142193 non-null  object
#  1   Location       142193 non-null  object
#  2   MinTemp        141556 non-null  float64
#  3   MaxTemp        141871 non-null  float64
#  4   Rainfall       140787 non-null  float64
#  5   Evaporation    81350 non-null   float64
#  6   Sunshine       74377 non-null   float64
#  7   WindGustDir    132863 non-null  object
#  8   WindGustSpeed  132923 non-null  float64
#  9   WindDir9am     132180 non-null  object
#  10  WindDir3pm     138415 non-null  object
#  11  WindSpeed9am   140845 non-null  float64
#  12  WindSpeed3pm   139563 non-null  float64
#  13  Humidity9am    140419 non-null  float64
#  14  Humidity3pm    138583 non-null  float64
#  15  Pressure9am    128179 non-null  float64
#  16  Pressure3pm    128212 non-null  float64
#  17  Cloud9am       88536 non-null   float64
#  18  Cloud3pm       85099 non-null   float64
#  19  Temp9am        141289 non-null  float64
#  20  Temp3pm        139467 non-null  float64
#  21  RainToday      140787 non-null  object
#  22  RISK_MM        142193 non-null  float64
#  23  RainTomorrow   142193 non-null  object
# dtypes: float64(17), object(7)
# memory usage: 26.0+ MB

# %% [markdown]
# # Drop RISK_MM variable

# %%
df.drop(["RISK_MM"],axis=1,inplace=True)

# %%
df
# Out:
#               Date Location  MinTemp  MaxTemp  Rainfall  Evaporation  \
# 0       2008-12-01   Albury     13.4     22.9       0.6          NaN
# 1       2008-12-02   Albury      7.4     25.1       0.0          NaN
# 2       2008-12-03   Albury     12.9     25.7       0.0          NaN
# 3       2008-12-04   Albury      9.2     28.0       0.0          NaN
# 4       2008-12-05   Albury     17.5     32.3       1.0          NaN
# ...            ...      ...      ...      ...       ...          ...
# 142188  2017-06-20    Uluru      3.5     21.8       0.0          NaN
# 142189  2017-06-21    Uluru      2.8     23.4       0.0          NaN
# 142190  2017-06-22    Uluru      3.6     25.3       0.0          NaN
# 142191  2017-06-23    Uluru      5.4     26.9       0.0          NaN
# 142192  2017-06-24    Uluru      7.8     27.0       0.0          NaN
#
#         Sunshine WindGustDir  WindGustSpeed WindDir9am  ... Humidity9am  \
# 0            NaN           W           44.0          W  ...        71.0
# 1            NaN         WNW           44.0        NNW  ...        44.0
# 2            NaN         WSW           46.0          W  ...        38.0
# 3            NaN          NE           24.0         SE  ...        45.0
# 4            NaN           W           41.0        ENE  ...        82.0
# ...          ...         ...            ...        ...  ...         ...
# 142188       NaN           E           31.0        ESE  ...        59.0
# 142189       NaN           E           31.0         SE  ...        51.0
# 142190       NaN         NNW           22.0         SE  ...        56.0
# 142191       NaN           N           37.0         SE  ...        53.0
# 142192       NaN          SE           28.0        SSE  ...        51.0
#
#         Humidity3pm  Pressure9am  Pressure3pm  Cloud9am  Cloud3pm  Temp9am  \
# 0              22.0       1007.7       1007.1       8.0       NaN     16.9
# 1              25.0       1010.6       1007.8       NaN       NaN     17.2
# 2              30.0       1007.6       1008.7       NaN       2.0     21.0
# 3              16.0       1017.6       1012.8       NaN       NaN     18.1
# 4              33.0       1010.8       1006.0       7.0       8.0     17.8
# ...             ...          ...          ...       ...       ...      ...
# 142188         27.0       1024.7       1021.2       NaN       NaN      9.4
# 142189         24.0       1024.6       1020.3       NaN       NaN     10.1
# 142190         21.0       1023.5       1019.1       NaN       NaN     10.9
# 142191         24.0       1021.0       1016.8       NaN       NaN     12.5
# 142192         24.0       1019.4       1016.5       3.0       2.0     15.1
#
#         Temp3pm  RainToday  RainTomorrow
# 0          21.8         No            No
# 1          24.3         No            No
# 2          23.2         No            No
# 3          26.5         No            No
# 4          29.7         No            No
# ...         ...        ...           ...
# 142188     20.9         No            No
# 142189     22.4         No            No
# 142190     24.5         No            No
# 142191     26.1         No            No
# 142192     26.0         No            No
#
# [142193 rows x 23 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 23 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           142193 non-null  object
#  1   Location       142193 non-null  object
#  2   MinTemp        141556 non-null  float64
#  3   MaxTemp        141871 non-null  float64
#  4   Rainfall       140787 non-null  float64
#  5   Evaporation    81350 non-null   float64
#  6   Sunshine       74377 non-null   float64
#  7   WindGustDir    132863 non-null  object
#  8   WindGustSpeed  132923 non-null  float64
#  9   WindDir9am     132180 non-null  object
#  10  WindDir3pm     138415 non-null  object
#  11  WindSpeed9am   140845 non-null  float64
#  12  WindSpeed3pm   139563 non-null  float64
#  13  Humidity9am    140419 non-null  float64
#  14  Humidity3pm    138583 non-null  float64
#  15  Pressure9am    128179 non-null  float64
#  16  Pressure3pm    128212 non-null  float64
#  17  Cloud9am       88536 non-null   float64
#  18  Cloud3pm       85099 non-null   float64
#  19  Temp9am        141289 non-null  float64
#  20  Temp3pm        139467 non-null  float64
#  21  RainToday      140787 non-null  object
#  22  RainTomorrow   142193 non-null  object
# dtypes: float64(16), object(7)
# memory usage: 25.0+ MB

# %% [markdown]
# # Types of variables

# %%
#Categorical,Numerical

# %% [markdown]
# # find categorical variables

# %%
categorical=[var for var in df.columns if df[var].dtype=="O"]
print('There are {} categorical variables'.format(len(categorical)))
print('The categorical variables are:',categorical)
# Out:
# There are 7 categorical variables
# The categorical variables are: ['Date', 'Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']

# %%
df[categorical].head()
# Out:
#          Date Location WindGustDir WindDir9am WindDir3pm RainToday  \
# 0  2008-12-01   Albury           W          W        WNW        No
# 1  2008-12-02   Albury         WNW        NNW        WSW        No
# 2  2008-12-03   Albury         WSW          W        WSW        No
# 3  2008-12-04   Albury          NE         SE          E        No
# 4  2008-12-05   Albury           W        ENE         NW        No
#
#   RainTomorrow
# 0           No
# 1           No
# 2           No
# 3           No
# 4           No

# %% [markdown]
# # Explore problems within categorical variables

# %% [markdown]
# # Missing values in categorical variables

# %%
#check missing values in categorical variables
df[categorical].isnull().sum()
# Out:
# Date                0
# Location            0
# WindGustDir      9330
# WindDir9am      10013
# WindDir3pm       3778
# RainToday        1406
# RainTomorrow        0
# dtype: int64

# %%
#print categorical variables containing missing values
cat1=[var for var in categorical if df[var].isnull().sum()!=0]
print(df[cat1].isnull().sum())
# Out:
# WindGustDir     9330
# WindDir9am     10013
# WindDir3pm      3778
# RainToday       1406
# dtype: int64

# %% [markdown]
# # Frequency counts of categorical variables

# %%
#view frequency of categorical variables
for var in categorical:
    print(df[var].value_counts())
# Out:
# Date
# 2013-12-01    49
# 2014-01-09    49
# 2014-01-11    49
# 2014-01-12    49
# 2014-01-13    49
#               ..
# 2007-11-29     1
# 2007-11-28     1
# 2007-11-27     1
# 2007-11-26     1
# 2008-01-31     1
# Name: count, Length: 3436, dtype: int64
# Location
# Canberra            3418
# Sydney              3337
# Perth               3193
# Darwin              3192
# Hobart              3188
# Brisbane            3161
# Adelaide            3090
# Bendigo             3034
# Townsville          3033
# AliceSprings        3031
# MountGambier        3030
# Launceston          3028
# Ballarat            3028
# Albany              3016
# Albury              3011
# PerthAirport        3009
# MelbourneAirport    3009
# Mildura             3007
# SydneyAirport       3005
# Nuriootpa           3002
# Sale                3000
# Watsonia            2999
# Tuggeranong         2998
# Portland            2996
# Woomera             2990
# Cairns              2988
# Cobar               2988
# Wollongong          2983
# GoldCoast           2980
# WaggaWagga          2976
# Penrith             2964
# NorfolkIsland       2964
# SalmonGums          2955
# Newcastle           2955
# CoffsHarbour        2953
# Witchcliffe         2952
# Richmond            2951
# Dartmoor            2943
# NorahHead           2929
# BadgerysCreek       2928
# MountGinini         2907
# Moree               2854
# Walpole             2819
# PearceRAAF          2762
# Williamtown         2553
# Melbourne           2435
# Nhil                1569
# Katherine           1559
# Uluru               1521
# Name: count, dtype: int64
# WindGustDir
# W      9780
# SE     9309
# E      9071
# N      9033
# SSE    8993
# S      8949
# WSW    8901
# SW     8797
# SSW    8610
# WNW    8066
# NW     8003
# ENE    7992
# ESE    7305
# NE     7060
# NNW    6561
# NNE    6433
# Name: count, dtype: int64
# WindDir9am
# N      11393
# SE      9162
# E       9024
# SSE     8966
# NW      8552
# S       8493
# W       8260
# SW      8237
# NNE     7948
# NNW     7840
# ENE     7735
# ESE     7558
# NE      7527
# SSW     7448
# WNW     7194
# WSW     6843
# Name: count, dtype: int64
# WindDir3pm
# SE     10663
# W       9911
# S       9598
# WSW     9329
# SW      9182
# SSE     9142
# N       8667
# WNW     8656
# NW      8468
# ESE     8382
# E       8342
# NE      8164
# SSW     8010
# NNW     7733
# ENE     7724
# NNE     6444
# Name: count, dtype: int64
# RainToday
# No     109332
# Yes     31455
# Name: count, dtype: int64
# RainTomorrow
# No     110316
# Yes     31877
# Name: count, dtype: int64

# %% [markdown]
# # Number of labels: cardinality

# %%
# check for cardinality in categorical variables
for var in categorical:
    print(var, "contains", len(df[var].unique()),"labels")
# Out:
# Date contains 3436 labels
# Location contains 49 labels
# WindGustDir contains 17 labels
# WindDir9am contains 17 labels
# WindDir3pm contains 17 labels
# RainToday contains 3 labels
# RainTomorrow contains 2 labels

# %% [markdown]
# # Feature Engineering of Date Variable

# %%
df["Date"].dtypes
# Out:
# dtype('O')

# %%
# parse the dates, currently coded as strings, into datetime format
df["Date"]=pd.to_datetime(df["Date"])

# %%
# extract year from date
df["Year"]=df["Date"].dt.year

# %%
df['Year'].head()
# Out:
# 0    2008
# 1    2008
# 2    2008
# 3    2008
# 4    2008
# Name: Year, dtype: int32

# %%
# extract month from date
df['Month']=df['Date'].dt.month
df['Month'].head()
# Out:
# 0    12
# 1    12
# 2    12
# 3    12
# 4    12
# Name: Month, dtype: int32

# %%
# extract day from date
df['Day']=df['Date'].dt.day
df['Day'].head()
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# Name: Day, dtype: int32

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 26 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Date           142193 non-null  datetime64[ns]
#  1   Location       142193 non-null  object
#  2   MinTemp        141556 non-null  float64
#  3   MaxTemp        141871 non-null  float64
#  4   Rainfall       140787 non-null  float64
#  5   Evaporation    81350 non-null   float64
#  6   Sunshine       74377 non-null   float64
#  7   WindGustDir    132863 non-null  object
#  8   WindGustSpeed  132923 non-null  float64
#  9   WindDir9am     132180 non-null  object
#  10  WindDir3pm     138415 non-null  object
#  11  WindSpeed9am   140845 non-null  float64
#  12  WindSpeed3pm   139563 non-null  float64
#  13  Humidity9am    140419 non-null  float64
#  14  Humidity3pm    138583 non-null  float64
#  15  Pressure9am    128179 non-null  float64
#  16  Pressure3pm    128212 non-null  float64
#  17  Cloud9am       88536 non-null   float64
#  18  Cloud3pm       85099 non-null   float64
#  19  Temp9am        141289 non-null  float64
#  20  Temp3pm        139467 non-null  float64
#  21  RainToday      140787 non-null  object
#  22  RainTomorrow   142193 non-null  object
#  23  Year           142193 non-null  int32
#  24  Month          142193 non-null  int32
#  25  Day            142193 non-null  int32
# dtypes: datetime64[ns](1), float64(16), int32(3), object(6)
# memory usage: 26.6+ MB

# %%
# drop the original Date variable
df.drop('Date',axis=1,inplace=True)

# %%
df.head()
# Out:
#   Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine WindGustDir  \
# 0   Albury     13.4     22.9       0.6          NaN       NaN           W
# 1   Albury      7.4     25.1       0.0          NaN       NaN         WNW
# 2   Albury     12.9     25.7       0.0          NaN       NaN         WSW
# 3   Albury      9.2     28.0       0.0          NaN       NaN          NE
# 4   Albury     17.5     32.3       1.0          NaN       NaN           W
#
#    WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  Cloud9am  Cloud3pm  \
# 0           44.0          W        WNW  ...       1007.1       8.0       NaN
# 1           44.0        NNW        WSW  ...       1007.8       NaN       NaN
# 2           46.0          W        WSW  ...       1008.7       NaN       2.0
# 3           24.0         SE          E  ...       1012.8       NaN       NaN
# 4           41.0        ENE         NW  ...       1006.0       7.0       8.0
#
#    Temp9am  Temp3pm  RainToday  RainTomorrow  Year  Month  Day
# 0     16.9     21.8         No            No  2008     12    1
# 1     17.2     24.3         No            No  2008     12    2
# 2     21.0     23.2         No            No  2008     12    3
# 3     18.1     26.5         No            No  2008     12    4
# 4     17.8     29.7         No            No  2008     12    5
#
# [5 rows x 25 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 142193 entries, 0 to 142192
# Data columns (total 25 columns):
#  #   Column         Non-Null Count   Dtype
# ---  ------         --------------   -----
#  0   Location       142193 non-null  object
#  1   MinTemp        141556 non-null  float64
#  2   MaxTemp        141871 non-null  float64
#  3   Rainfall       140787 non-null  float64
#  4   Evaporation    81350 non-null   float64
#  5   Sunshine       74377 non-null   float64
#  6   WindGustDir    132863 non-null  object
#  7   WindGustSpeed  132923 non-null  float64
#  8   WindDir9am     132180 non-null  object
#  9   WindDir3pm     138415 non-null  object
#  10  WindSpeed9am   140845 non-null  float64
#  11  WindSpeed3pm   139563 non-null  float64
#  12  Humidity9am    140419 non-null  float64
#  13  Humidity3pm    138583 non-null  float64
#  14  Pressure9am    128179 non-null  float64
#  15  Pressure3pm    128212 non-null  float64
#  16  Cloud9am       88536 non-null   float64
#  17  Cloud3pm       85099 non-null   float64
#  18  Temp9am        141289 non-null  float64
#  19  Temp3pm        139467 non-null  float64
#  20  RainToday      140787 non-null  object
#  21  RainTomorrow   142193 non-null  object
#  22  Year           142193 non-null  int32
#  23  Month          142193 non-null  int32
#  24  Day            142193 non-null  int32
# dtypes: float64(16), int32(3), object(6)
# memory usage: 25.5+ MB

# %% [markdown]
# # Explore Categorical Variables

# %%
# find categorical variables
categorical=[var for var in df.columns if df[var].dtype=='O']
print('There are {} categorical variables\n'.format(len(categorical)))
print('The categorical variables are :', categorical)
# Out:
# There are 6 categorical variables
#
# The categorical variables are : ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday', 'RainTomorrow']

# %%
# check for missing values in categorical variables 
df[categorical].isnull().sum()
# Out:
# Location            0
# WindGustDir      9330
# WindDir9am      10013
# WindDir3pm       3778
# RainToday        1406
# RainTomorrow        0
# dtype: int64

# %%
# print number of labels in Location variable
print('Location contains', len(df["Location"].unique()), 'labels')
# Out:
# Location contains 49 labels

# %%
df["Location"].unique()
# Out:
# array(['Albury', 'BadgerysCreek', 'Cobar', 'CoffsHarbour', 'Moree',
#        'Newcastle', 'NorahHead', 'NorfolkIsland', 'Penrith', 'Richmond',
#        'Sydney', 'SydneyAirport', 'WaggaWagga', 'Williamtown',
#        'Wollongong', 'Canberra', 'Tuggeranong', 'MountGinini', 'Ballarat',
#        'Bendigo', 'Sale', 'MelbourneAirport', 'Melbourne', 'Mildura',
#        'Nhil', 'Portland', 'Watsonia', 'Dartmoor', 'Brisbane', 'Cairns',
#        'GoldCoast', 'Townsville', 'Adelaide', 'MountGambier', 'Nuriootpa',
#        'Woomera', 'Albany', 'Witchcliffe', 'PearceRAAF', 'PerthAirport',
#        'Perth', 'SalmonGums', 'Walpole', 'Hobart', 'Launceston',
#        'AliceSprings', 'Darwin', 'Katherine', 'Uluru'], dtype=object)

# %%
# check frequency distribution of values in Location variable
df["Location"].value_counts()
# Out:
# Location
# Canberra            3418
# Sydney              3337
# Perth               3193
# Darwin              3192
# Hobart              3188
# Brisbane            3161
# Adelaide            3090
# Bendigo             3034
# Townsville          3033
# AliceSprings        3031
# MountGambier        3030
# Launceston          3028
# Ballarat            3028
# Albany              3016
# Albury              3011
# PerthAirport        3009
# MelbourneAirport    3009
# Mildura             3007
# SydneyAirport       3005
# Nuriootpa           3002
# Sale                3000
# Watsonia            2999
# Tuggeranong         2998
# Portland            2996
# Woomera             2990
# Cairns              2988
# Cobar               2988
# Wollongong          2983
# GoldCoast           2980
# WaggaWagga          2976
# Penrith             2964
# NorfolkIsland       2964
# SalmonGums          2955
# Newcastle           2955
# CoffsHarbour        2953
# Witchcliffe         2952
# Richmond            2951
# Dartmoor            2943
# NorahHead           2929
# BadgerysCreek       2928
# MountGinini         2907
# Moree               2854
# Walpole             2819
# PearceRAAF          2762
# Williamtown         2553
# Melbourne           2435
# Nhil                1569
# Katherine           1559
# Uluru               1521
# Name: count, dtype: int64

# %%
# let's do One Hot Encoding of Location variable
# get k-1 dummy variables after One Hot Encoding 
pd.get_dummies(df["Location"], drop_first=True).head()
# Out:
#    Albany  Albury  AliceSprings  BadgerysCreek  Ballarat  Bendigo  Brisbane  \
# 0   False    True         False          False     False    False     False
# 1   False    True         False          False     False    False     False
# 2   False    True         False          False     False    False     False
# 3   False    True         False          False     False    False     False
# 4   False    True         False          False     False    False     False
#
#    Cairns  Canberra  Cobar  ...  Townsville  Tuggeranong  Uluru  WaggaWagga  \
# 0   False     False  False  ...       False        False  False       False
# 1   False     False  False  ...       False        False  False       False
# 2   False     False  False  ...       False        False  False       False
# 3   False     False  False  ...       False        False  False       False
# 4   False     False  False  ...       False        False  False       False
#
#    Walpole  Watsonia  Williamtown  Witchcliffe  Wollongong  Woomera
# 0    False     False        False        False       False    False
# 1    False     False        False        False       False    False
# 2    False     False        False        False       False    False
# 3    False     False        False        False       False    False
# 4    False     False        False        False       False    False
#
# [5 rows x 48 columns]

# %%
#df["WindGustDir"].nunique()
# Out:
# 16

# %%
#print number of labels in WindGustDir variable
print("WindGustDir contains",len(df["WindGustDir"].unique()),"labels")
# Out:
# WindGustDir contains 17 labels

# %%
#check labels in WindGustDir variable
df['WindGustDir'].unique()
# Out:
# array(['W', 'WNW', 'WSW', 'NE', 'NNW', 'N', 'NNE', 'SW', 'ENE', 'SSE',
#        'S', 'NW', 'SE', 'ESE', nan, 'E', 'SSW'], dtype=object)

# %%
# check frequency distribution of values in WindGustDir variable
df.WindGustDir.value_counts()
# Out:
# WindGustDir
# W      9780
# SE     9309
# E      9071
# N      9033
# SSE    8993
# S      8949
# WSW    8901
# SW     8797
# SSW    8610
# WNW    8066
# NW     8003
# ENE    7992
# ESE    7305
# NE     7060
# NNW    6561
# NNE    6433
# Name: count, dtype: int64

# %%
# let's do One Hot Encoding of WindGustDir variable
# get k-1 dummy variables after One Hot Encoding 
# also add an additional dummy variable to indicate there was missing data
# preview the dataset with head() method
pd.get_dummies(df["WindGustDir"], drop_first=True, dummy_na=True).head()
# Out:
#      ENE    ESE      N     NE    NNE    NNW     NW      S     SE    SSE  \
# 0  False  False  False  False  False  False  False  False  False  False
# 1  False  False  False  False  False  False  False  False  False  False
# 2  False  False  False  False  False  False  False  False  False  False
# 3  False  False  False   True  False  False  False  False  False  False
# 4  False  False  False  False  False  False  False  False  False  False
#
#      SSW     SW      W    WNW    WSW    NaN
# 0  False  False   True  False  False  False
# 1  False  False  False   True  False  False
# 2  False  False  False  False   True  False
# 3  False  False  False  False  False  False
# 4  False  False   True  False  False  False

# %%
#sum the number of 1s per boolean variable over the rows of the dataset
# it will tell us how many observations we have for each category
pd.get_dummies(df["WindGustDir"], drop_first=True, dummy_na=True).sum(axis=0)
# Out:
# ENE    7992
# ESE    7305
# N      9033
# NE     7060
# NNE    6433
# NNW    6561
# NW     8003
# S      8949
# SE     9309
# SSE    8993
# SSW    8610
# SW     8797
# W      9780
# WNW    8066
# WSW    8901
# NaN    9330
# dtype: int64

# %%
# print number of labels in WindDir9am variable
print('WindDir9am contains', len(df['WindDir9am'].unique()), 'labels')
# Out:
# WindDir9am contains 17 labels

# %%
# check labels in WindDir9am variable
df['WindDir9am'].unique()
# Out:
# array(['W', 'NNW', 'SE', 'ENE', 'SW', 'SSE', 'S', 'NE', nan, 'SSW', 'N',
#        'WSW', 'ESE', 'E', 'NW', 'WNW', 'NNE'], dtype=object)

# %%
# check frequency distribution of values in WindDir9am variable
df['WindDir9am'].value_counts()
# Out:
# WindDir9am
# N      11393
# SE      9162
# E       9024
# SSE     8966
# NW      8552
# S       8493
# W       8260
# SW      8237
# NNE     7948
# NNW     7840
# ENE     7735
# ESE     7558
# NE      7527
# SSW     7448
# WNW     7194
# WSW     6843
# Name: count, dtype: int64

# %%
# let's do One Hot Encoding of WindDir9am variable
# get k-1 dummy variables after One Hot Encoding 
# also add an additional dummy variable to indicate there was missing data
# preview the dataset with head() method
pd.get_dummies(df["WindDir9am"], drop_first=True, dummy_na=True).head()
# Out:
#      ENE    ESE      N     NE    NNE    NNW     NW      S     SE    SSE  \
# 0  False  False  False  False  False  False  False  False  False  False
# 1  False  False  False  False  False   True  False  False  False  False
# 2  False  False  False  False  False  False  False  False  False  False
# 3  False  False  False  False  False  False  False  False   True  False
# 4   True  False  False  False  False  False  False  False  False  False
#
#      SSW     SW      W    WNW    WSW    NaN
# 0  False  False   True  False  False  False
# 1  False  False  False  False  False  False
# 2  False  False   True  False  False  False
# 3  False  False  False  False  False  False
# 4  False  False  False  False  False  False

# %%
# sum the number of 1s per boolean variable over the rows of the dataset
# it will tell us how many observations we have for each category
pd.get_dummies(df["WindDir9am"], drop_first=True, dummy_na=True).sum(axis=0)
# Out:
# ENE     7735
# ESE     7558
# N      11393
# NE      7527
# NNE     7948
# NNW     7840
# NW      8552
# S       8493
# SE      9162
# SSE     8966
# SSW     7448
# SW      8237
# W       8260
# WNW     7194
# WSW     6843
# NaN    10013
# dtype: int64

# %%
# print number of labels in WindDir3pm variable
print('WindDir3pm contains', len(df['WindDir3pm'].unique()), 'labels')
# Out:
# WindDir3pm contains 17 labels

# %%
# check labels in WindDir3pm variable
df['WindDir3pm'].unique()
# Out:
# array(['WNW', 'WSW', 'E', 'NW', 'W', 'SSE', 'ESE', 'ENE', 'NNW', 'SSW',
#        'SW', 'SE', 'N', 'S', 'NNE', nan, 'NE'], dtype=object)

# %%
# check frequency distribution of values in WindDir3pm variable
df['WindDir3pm'].value_counts()
# Out:
# WindDir3pm
# SE     10663
# W       9911
# S       9598
# WSW     9329
# SW      9182
# SSE     9142
# N       8667
# WNW     8656
# NW      8468
# ESE     8382
# E       8342
# NE      8164
# SSW     8010
# NNW     7733
# ENE     7724
# NNE     6444
# Name: count, dtype: int64

# %%
# let's do One Hot Encoding of WindDir3pm variable
# get k-1 dummy variables after One Hot Encoding 
# also add an additional dummy variable to indicate there was missing data
# preview the dataset with head() method
pd.get_dummies(df["WindDir3pm"], drop_first=True, dummy_na=True).head()
# Out:
#      ENE    ESE      N     NE    NNE    NNW     NW      S     SE    SSE  \
# 0  False  False  False  False  False  False  False  False  False  False
# 1  False  False  False  False  False  False  False  False  False  False
# 2  False  False  False  False  False  False  False  False  False  False
# 3  False  False  False  False  False  False  False  False  False  False
# 4  False  False  False  False  False  False   True  False  False  False
#
#      SSW     SW      W    WNW    WSW    NaN
# 0  False  False  False   True  False  False
# 1  False  False  False  False   True  False
# 2  False  False  False  False   True  False
# 3  False  False  False  False  False  False
# 4  False  False  False  False  False  False

# %%
#sum the number of 1s per boolean variable over the rows of the dataset
# it will tell us how many observations we have for each category
pd.get_dummies(df["WindDir3pm"], drop_first=True, dummy_na=True).sum(axis=0)
# Out:
# ENE     7724
# ESE     8382
# N       8667
# NE      8164
# NNE     6444
# NNW     7733
# NW      8468
# S       9598
# SE     10663
# SSE     9142
# SSW     8010
# SW      9182
# W       9911
# WNW     8656
# WSW     9329
# NaN     3778
# dtype: int64

# %%
# print number of labels in RainToday variable
print('RainToday contains', len(df['RainToday'].unique()), 'labels')
# Out:
# RainToday contains 3 labels

# %%
# check labels in WindGustDir variable
df['RainToday'].unique()
# Out:
# array(['No', 'Yes', nan], dtype=object)

# %%
# check frequency distribution of values in WindGustDir variable
df["RainToday"].value_counts()
# Out:
# RainToday
# No     109332
# Yes     31455
# Name: count, dtype: int64

# %%
# let's do One Hot Encoding of RainToday variable
# get k-1 dummy variables after One Hot Encoding 
# also add an additional dummy variable to indicate there was missing data
# preview the dataset with head() method
pd.get_dummies(df["RainToday"], drop_first=True, dummy_na=True).head()
# Out:
#      Yes    NaN
# 0  False  False
# 1  False  False
# 2  False  False
# 3  False  False
# 4  False  False

# %%
# sum the number of 1s per boolean variable over the rows of the dataset
# it will tell us how many observations we have for each category
pd.get_dummies(df["RainToday"], drop_first=True, dummy_na=True).sum(axis=0)
# Out:
# Yes    31455
# NaN     1406
# dtype: int64

# %% [markdown]
# # Explore Numerical Variables

# %%
Numerical=[var for var in df.columns if df[var].dtype!="O"]
print("There are {} numerical variables".format(len(Numerical)))
print('These are',Numerical)
# Out:
# There are 19 numerical variables
# These are ['MinTemp', 'MaxTemp', 'Rainfall', 'Evaporation', 'Sunshine', 'WindGustSpeed', 'WindSpeed9am', 'WindSpeed3pm', 'Humidity9am', 'Humidity3pm', 'Pressure9am', 'Pressure3pm', 'Cloud9am', 'Cloud3pm', 'Temp9am', 'Temp3pm', 'Year', 'Month', 'Day']

# %%
# view the numerical variables
df[Numerical].head()
# Out:
#    MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 0     13.4     22.9       0.6          NaN       NaN           44.0
# 1      7.4     25.1       0.0          NaN       NaN           44.0
# 2     12.9     25.7       0.0          NaN       NaN           46.0
# 3      9.2     28.0       0.0          NaN       NaN           24.0
# 4     17.5     32.3       1.0          NaN       NaN           41.0
#
#    WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# 0          20.0          24.0         71.0         22.0       1007.7
# 1           4.0          22.0         44.0         25.0       1010.6
# 2          19.0          26.0         38.0         30.0       1007.6
# 3          11.0           9.0         45.0         16.0       1017.6
# 4           7.0          20.0         82.0         33.0       1010.8
#
#    Pressure3pm  Cloud9am  Cloud3pm  Temp9am  Temp3pm  Year  Month  Day
# 0       1007.1       8.0       NaN     16.9     21.8  2008     12    1
# 1       1007.8       NaN       NaN     17.2     24.3  2008     12    2
# 2       1008.7       NaN       2.0     21.0     23.2  2008     12    3
# 3       1012.8       NaN       NaN     18.1     26.5  2008     12    4
# 4       1006.0       7.0       8.0     17.8     29.7  2008     12    5

# %% [markdown]
# # Explore problems within numerical variables

# %% [markdown]
# # Missing values in numerical variables

# %%
df[Numerical].isnull().sum()
# Out:
# MinTemp            637
# MaxTemp            322
# Rainfall          1406
# Evaporation      60843
# Sunshine         67816
# WindGustSpeed     9270
# WindSpeed9am      1348
# WindSpeed3pm      2630
# Humidity9am       1774
# Humidity3pm       3610
# Pressure9am      14014
# Pressure3pm      13981
# Cloud9am         53657
# Cloud3pm         57094
# Temp9am            904
# Temp3pm           2726
# Year                 0
# Month                0
# Day                  0
# dtype: int64

# %% [markdown]
# # Outliers in numerical variables

# %%
# view summary statistics in numerical variables
print(round(df[Numerical].describe()),2)
# Out:
#         MinTemp   MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# count  141556.0  141871.0  140787.0      81350.0   74377.0       132923.0
# mean       12.0      23.0       2.0          5.0       8.0           40.0
# std         6.0       7.0       8.0          4.0       4.0           14.0
# min        -8.0      -5.0       0.0          0.0       0.0            6.0
# 25%         8.0      18.0       0.0          3.0       5.0           31.0
# 50%        12.0      23.0       0.0          5.0       8.0           39.0
# 75%        17.0      28.0       1.0          7.0      11.0           48.0
# max        34.0      48.0     371.0        145.0      14.0          135.0
#
#        WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  Pressure9am  \
# count      140845.0      139563.0     140419.0     138583.0     128179.0
# mean           14.0          19.0         69.0         51.0       1018.0
# std             9.0           9.0         19.0         21.0          7.0
# min             0.0           0.0          0.0          0.0        980.0
# 25%             7.0          13.0         57.0         37.0       1013.0
# 50%            13.0          19.0         70.0         52.0       1018.0
# 75%            19.0          24.0         83.0         66.0       1022.0
# max           130.0          87.0        100.0        100.0       1041.0
#
#        Pressure3pm  Cloud9am  Cloud3pm   Temp9am   Temp3pm      Year  \
# count     128212.0   88536.0   85099.0  141289.0  139467.0  142193.0
# mean        1015.0       4.0       5.0      17.0      22.0    2013.0
# std            7.0       3.0       3.0       6.0       7.0       3.0
# min          977.0       0.0       0.0      -7.0      -5.0    2007.0
# 25%         1010.0       1.0       2.0      12.0      17.0    2011.0
# 50%         1015.0       5.0       5.0      17.0      21.0    2013.0
# 75%         1020.0       7.0       7.0      22.0      26.0    2015.0
# max         1040.0       9.0       9.0      40.0      47.0    2017.0
#
#           Month       Day
# count  142193.0  142193.0
# mean        6.0      16.0
# std         3.0       9.0
# min         1.0       1.0
# 25%         3.0       8.0
# 50%         6.0      16.0
# 75%         9.0      23.0
# max        12.0      31.0   2

# %%
# draw boxplots to visualize outliers
plt.figure(figsize=(15,10))
plt.subplot(2, 2, 1)
sns.boxplot(df['Rainfall'])
plt.title('Rainfall')

plt.subplot(2, 2, 2)
sns.boxplot(df['Evaporation'])
plt.title('Evaporation')

plt.subplot(2, 2, 3)
sns.boxplot(df['WindSpeed9am'])
plt.title('WindSpeed9am')
          
plt.subplot(2, 2, 4)
sns.boxplot(df['WindSpeed3pm'])
plt.title('WindSpeed3pm')
# Out:
# Text(0.5, 1.0, 'WindSpeed3pm')

# %%
# draw distributionplots to visualize outliers
plt.figure(figsize=(15,10))
plt.subplot(2, 2, 1)
sns.distplot(df['Rainfall'])

plt.subplot(2, 2, 2)
sns.distplot(df['Evaporation'])

plt.subplot(2, 2, 3)
sns.distplot(df['WindSpeed9am'])
          
plt.subplot(2, 2, 4)
sns.distplot(df['WindSpeed3pm'])
# Out:
# C:\Users\Aqsa Kanwal\AppData\Local\Temp\ipykernel_2312\2644516375.py:4: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Rainfall'])
# C:\Users\Aqsa Kanwal\AppData\Local\Temp\ipykernel_2312\2644516375.py:7: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Evaporation'])
# C:\Users\Aqsa Kanwal\AppData\Local\Temp\ipykernel_2312\2644516375.py:10: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['WindSpeed9am'])
# C:\Users\Aqsa Kanwal\AppData\Local\Temp\ipykernel_2312\2644516375.py:13: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['WindSpeed3pm'])
# <Axes: xlabel='WindSpeed3pm', ylabel='Density'>

# %%
# find outliers for Rainfall variable
#iqr=percentile75-percentile25
#maximum=q3+k*iqr
#minimum=q1-k*iqr

# %%
percentile75=df["Rainfall"].quantile(0.75)
percentile25=df["Rainfall"].quantile(0.25)

# %%
iqr=percentile75-percentile25

# %%
iqr
# Out:
# 0.8

# %%
#k=1.5

# %%
#Maximum= percentile75+1.5*iqr
#Minimum= percentile25-1.5*iqr

# %%
#Maximum
# Out:
# 2.0

# %%
#Minimum
# Out:
# -1.2000000000000002

# %%
#print("Rainfall outliers values > {Maximum} < {Minimum}".format(Maximum=Maximum,Minimum=Minimum))
# Out:
# Rainfall outliers values > 2.0 < -1.2000000000000002

# %%
#k=3
IQR=df["Rainfall"].quantile(0.75) - df["Rainfall"].quantile(0.25)

# %%
IQR
# Out:
# 0.8

# %%
Minimum=df["Rainfall"].quantile(0.25)-(IQR*3)
Maximum=df["Rainfall"].quantile(0.75)+(IQR*3)
print('Rainfall outliers are values < {Minimum} or > {Maximum}'.format(Minimum=Minimum,Maximum=Maximum))
# Out:
# Rainfall outliers are values < -2.4000000000000004 or > 3.2

# %%
df[(df["Rainfall"]<Minimum) | (df["Rainfall"]>Maximum)]
# Out:
#        Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 12       Albury     15.9     18.6      15.6          NaN       NaN
# 13       Albury     12.6     21.0       3.6          NaN       NaN
# 16       Albury     13.5     22.9      16.8          NaN       NaN
# 17       Albury     11.2     22.5      10.6          NaN       NaN
# 52       Albury     18.8     35.2       6.4          NaN       NaN
# ...         ...      ...      ...       ...          ...       ...
# 142060    Uluru     22.2     39.4       6.2          NaN       NaN
# 142125    Uluru     15.2     21.5       6.8          NaN       NaN
# 142126    Uluru     17.7     26.9      12.6          NaN       NaN
# 142127    Uluru     18.6     28.6      34.6          NaN       NaN
# 142128    Uluru     18.1     29.6       3.8          NaN       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  \
# 12               W           61.0        NNW        NNW  ...        993.0
# 13              SW           44.0          W        SSW  ...       1001.8
# 16               W           63.0          N        WNW  ...       1002.2
# 17             SSE           43.0        WSW         SW  ...       1009.7
# 52             WNW           52.0          S         NW  ...       1003.9
# ...            ...            ...        ...        ...  ...          ...
# 142060           S           30.0          S          W  ...       1004.9
# 142125         ENE           30.0         NE        ENE  ...       1015.3
# 142126           S           35.0          E        SSW  ...       1014.7
# 142127           E           46.0          E          E  ...       1015.8
# 142128         SSE           35.0        SSE         SE  ...       1014.5
#
#         Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  Year  \
# 12           8.0       8.0     17.4     15.8        Yes           Yes  2008
# 13           NaN       7.0     15.8     19.8        Yes            No  2008
# 16           8.0       1.0     18.0     21.5        Yes           Yes  2008
# 17           NaN       2.0     15.5     21.0        Yes            No  2008
# 52           NaN       NaN     22.8     33.0        Yes            No  2009
# ...          ...       ...      ...      ...        ...           ...   ...
# 142060       NaN       4.0     28.6     38.7        Yes            No  2017
# 142125       3.0       8.0     19.0     21.2        Yes           Yes  2017
# 142126       7.0       8.0     19.0     26.0        Yes           Yes  2017
# 142127       8.0       5.0     19.8     26.9        Yes           Yes  2017
# 142128       1.0       8.0     20.3     28.0        Yes            No  2017
#
#         Month  Day
# 12         12   13
# 13         12   14
# 16         12   18
# 17         12   19
# 52          1   23
# ...       ...  ...
# 142060      2   11
# 142125      4   18
# 142126      4   19
# 142127      4   20
# 142128      4   21
#
# [20462 rows x 25 columns]

# %%
# find outliers for Evaporation variable
IQR=df["Evaporation"].quantile(0.75)-df["Evaporation"].quantile(0.25)

# %%
Minimum=df["Evaporation"].quantile(0.25)-(IQR*3)
Maximum=df["Evaporation"].quantile(0.75)+(IQR*3)

# %%
print('Evaporation outliers are values < {Minimum} or > {Maximum}'.format(Minimum=Minimum,Maximum=Maximum))
# Out:
# Evaporation outliers are values < -11.800000000000002 or > 21.800000000000004

# %%
df[(df["Evaporation"]<Minimum) | (df["Evaporation"]>Maximum)]
# Out:
#             Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 6698           Cobar     22.1     39.1       0.0         64.8       NaN
# 6704           Cobar     22.0     28.2       0.0         32.0       NaN
# 6895           Cobar     12.7     31.6       0.0         26.2       NaN
# 6903           Cobar      7.7     24.5       0.0         24.6       NaN
# 6950           Cobar     16.4     32.2       0.0         23.3       NaN
# ...              ...      ...      ...       ...          ...       ...
# 135860  AliceSprings     19.1     34.2       0.0         24.0       NaN
# 139363     Katherine     23.4     40.3       0.0         30.6       NaN
# 140073     Katherine     23.0     40.0       0.0         28.0       NaN
# 140494     Katherine     23.7     33.2      15.0         24.4       NaN
# 140571     Katherine     23.0     35.0      79.0         31.0       NaN
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  \
# 6698             N           37.0        NNE        NNW  ...       1011.6
# 6704           SSW           44.0        SSE          S  ...       1017.3
# 6895           WNW           41.0         NW          W  ...       1015.8
# 6903             E           48.0          E        ENE  ...       1015.9
# 6950            SW           28.0        ESE         SW  ...       1013.9
# ...            ...            ...        ...        ...  ...          ...
# 135860         WSW           48.0        NNW        NNW  ...       1011.7
# 139363         ENE           43.0          N         SE  ...       1006.4
# 140073         ENE           44.0        NNW          E  ...       1009.4
# 140494         WNW           37.0          N         NW  ...       1004.3
# 140571         ESE           22.0        SSE         SE  ...       1007.1
#
#         Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  Year  \
# 6698         0.0       1.0     30.1     36.9         No            No  2011
# 6704         7.0       7.0     24.3     21.3         No            No  2011
# 6895         6.0       7.0     25.1     30.1         No            No  2011
# 6903         6.0       1.0     15.8     23.3         No            No  2011
# 6950         7.0       7.0     24.4     30.9         No            No  2011
# ...          ...       ...      ...      ...        ...           ...   ...
# 135860       NaN       2.0     27.6     32.8         No            No  2017
# 139363       2.0       2.0     30.6     40.2         No            No  2013
# 140073       0.0       NaN     31.5      NaN         No            No  2015
# 140494       8.0       NaN     27.4      NaN        Yes           Yes  2016
# 140571       3.0       NaN     27.5      NaN        Yes            No  2017
#
#         Month  Day
# 6698        1   31
# 6704        2    6
# 6895        9   18
# 6903        9   26
# 6950       11   12
# ...       ...  ...
# 135860      4   24
# 139363     11    6
# 140073     10   22
# 140494     12   22
# 140571      3   14
#
# [471 rows x 25 columns]

# %%
# find outliers for WindSpeed9am variable
IQR=df["WindSpeed9am"].quantile(0.75)-df["WindSpeed9am"].quantile(0.25)

# %%
Minimum=df["WindSpeed9am"].quantile(0.25)-(IQR*3)
Maximum=df["WindSpeed9am"].quantile(0.75)+(IQR*3)

# %%
print('WindSpeed9am outliers are values < {Minimum} or > {Maximum}'.format(Minimum=Minimum,Maximum=Maximum))
# Out:
# WindSpeed9am outliers are values < -29.0 or > 55.0

# %%
df[(df["WindSpeed9am"]<Minimum) | (df["WindSpeed9am"]>Maximum)]
# Out:
#             Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 11493   CoffsHarbour     15.8     20.7      46.8          NaN       NaN
# 15030      Newcastle     16.4     19.5       0.0          NaN       NaN
# 15033      Newcastle     11.8     22.2       0.0          NaN       NaN
# 15034      Newcastle      9.2     19.4       0.0          NaN       NaN
# 15353      Newcastle     11.4     18.0       0.4          NaN       NaN
# ...              ...      ...      ...       ...          ...       ...
# 108668        Albany      6.7     12.0      18.0          NaN       NaN
# 108730        Albany      8.7     13.6       4.2          NaN       NaN
# 108731        Albany      6.8     15.3       9.8          NaN       NaN
# 108738        Albany      9.0     14.8      13.0          NaN       NaN
# 137194        Darwin     24.0     28.7     182.2          NaN       0.0
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  \
# 11493           NE           85.0        NNE        ENE  ...       1008.7
# 15030          NaN            NaN         NW         NW  ...          NaN
# 15033          NaN            NaN         NW         NW  ...          NaN
# 15034          NaN            NaN         NW         NW  ...          NaN
# 15353          NaN            NaN         SW         NW  ...          NaN
# ...            ...            ...        ...        ...  ...          ...
# 108668         NaN            NaN        WSW        NaN  ...       1019.1
# 108730         NaN            NaN        WSW        NaN  ...        997.1
# 108731         NaN            NaN        WSW        NaN  ...       1011.5
# 108738         NaN            NaN        WSW        NaN  ...       1018.3
# 137194         WNW           93.0        WNW          W  ...        997.4
#
#         Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  Year  \
# 11493        8.0       8.0     18.8     19.5        Yes           Yes  2016
# 15030        0.0       2.0     16.6     19.0         No            No  2009
# 15033        8.0       2.0     19.6     20.0         No            No  2009
# 15034        2.0       1.0     14.5     18.5         No            No  2009
# 15353        5.0       5.0     13.9     16.2         No            No  2010
# ...          ...       ...      ...      ...        ...           ...   ...
# 108668       6.0       NaN     10.9      NaN        Yes           Yes  2016
# 108730       5.0       NaN     10.8      NaN        Yes           Yes  2016
# 108731       6.0       NaN     11.8      NaN        Yes           Yes  2016
# 108738       6.0       NaN     12.8      NaN        Yes            No  2016
# 137194       7.0       8.0     27.1     28.1        Yes           Yes  2012
#
#         Month  Day
# 11493       6    4
# 15030       9   23
# 15033       9   26
# 15034       9   27
# 15353       8   12
# ...       ...  ...
# 108668      7   31
# 108730     10    1
# 108731     10    2
# 108738     10    9
# 137194      1   25
#
# [107 rows x 25 columns]

# %%
# find outliers for WindSpeed3pm variable
IQR=df["WindSpeed3pm"].quantile(0.75)-df["WindSpeed3pm"].quantile(0.25)

# %%
Minimum=df["WindSpeed3pm"].quantile(0.25)-(IQR*3)
Maximum=df["WindSpeed3pm"].quantile(0.75)+(IQR*3)

# %%
print('WindSpeed3pm outliers are values < {Minimum} or > {Maximum}'.format(Minimum=Minimum,Maximum=Maximum))
# Out:
# WindSpeed3pm outliers are values < -20.0 or > 57.0

# %%
df[(df["WindSpeed3pm"]<Minimum) | (df["WindSpeed3pm"]>Maximum)]
# Out:
#             Location  MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  \
# 11553   CoffsHarbour     14.1     16.8       8.6          NaN       NaN
# 15030      Newcastle     16.4     19.5       0.0          NaN       NaN
# 15033      Newcastle     11.8     22.2       0.0          NaN       NaN
# 15670      Newcastle      8.1     23.2       0.0          NaN       NaN
# 15711      Newcastle     16.2     29.4       0.0          NaN       NaN
# ...              ...      ...      ...       ...          ...       ...
# 108264        Albany      9.2     13.8      17.8          3.8       2.6
# 112161    PearceRAAF     13.4     19.2       0.8          NaN       2.2
# 125318       Walpole     12.6     19.7       8.6          NaN       NaN
# 128892        Hobart      6.3     12.5      14.6          NaN       8.8
# 132945  AliceSprings     24.2     39.6       1.4          9.4      12.0
#
#        WindGustDir  WindGustSpeed WindDir9am WindDir3pm  ...  Pressure3pm  \
# 11553          NaN            NaN        WSW        SSW  ...       1006.8
# 15030          NaN            NaN         NW         NW  ...          NaN
# 15033          NaN            NaN         NW         NW  ...          NaN
# 15670          NaN            NaN        NaN          W  ...          NaN
# 15711          NaN            NaN        NaN         NW  ...          NaN
# ...            ...            ...        ...        ...  ...          ...
# 108264         NaN            NaN        SSW         SW  ...       1021.2
# 112161         WNW           85.0         NW        WNW  ...       1002.6
# 125318          NW          104.0         NW        WNW  ...        997.0
# 128892         WNW           94.0         NW        WNW  ...        994.8
# 132945          SE           93.0          E         SE  ...       1007.1
#
#         Cloud9am  Cloud3pm  Temp9am  Temp3pm  RainToday  RainTomorrow  Year  \
# 11553        8.0       8.0     16.2     14.0        Yes           Yes  2016
# 15030        0.0       2.0     16.6     19.0         No            No  2009
# 15033        8.0       2.0     19.6     20.0         No            No  2009
# 15670        0.0       0.0     12.2     22.6         No            No  2011
# 15711        5.0       4.0     19.4     27.6         No            No  2011
# ...          ...       ...      ...      ...        ...           ...   ...
# 108264       6.0       7.0     12.5     11.2        Yes           Yes  2015
# 112161       7.0       7.0     17.2     18.6         No           Yes  2009
# 125318       NaN       NaN     14.7     17.0        Yes            No  2013
# 128892       7.0       2.0      7.5     11.2        Yes           Yes  2014
# 132945       1.0       6.0     32.9     31.2        Yes            No  2009
#
#         Month  Day
# 11553       8    3
# 15030       9   23
# 15033       9   26
# 15670       8    5
# 15711       9   20
# ...       ...  ...
# 108264      6   22
# 112161      9   10
# 125318      8   31
# 128892     10   28
# 132945      1   25
#
# [81 rows x 25 columns]

# %% [markdown]
# # Declare feature vector and target variable

# %%
X=df.drop(['RainTomorrow'], axis=1)
y=df['RainTomorrow']

# %% [markdown]
# # Split data into separate training and test set

# %%
# split X and y into training and testing sets
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.2,random_state=0)

# %%
# check the shape of X_train and X_test
X_train.shape, X_test.shape
# Out:
# ((113754, 24), (28439, 24))

# %% [markdown]
# # Feature Engineering

# %%
# check data types in X_train
X_train.dtypes
# Out:
# Location          object
# MinTemp          float64
# MaxTemp          float64
# Rainfall         float64
# Evaporation      float64
# Sunshine         float64
# WindGustDir       object
# WindGustSpeed    float64
# WindDir9am        object
# WindDir3pm        object
# WindSpeed9am     float64
# WindSpeed3pm     float64
# Humidity9am      float64
# Humidity3pm      float64
# Pressure9am      float64
# Pressure3pm      float64
# Cloud9am         float64
# Cloud3pm         float64
# Temp9am          float64
# Temp3pm          float64
# RainToday         object
# Year               int32
# Month              int32
# Day                int32
# dtype: object

# %%
# display categorical variables
categorical=[col for col in X_train.columns if X_train[col].dtypes == 'O']
categorical
# Out:
# ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday']

# %%
# display numerical variables
numerical=[col for col in X_train.columns if X_train[col].dtypes != 'O']
numerical
# Out:
# ['MinTemp',
#  'MaxTemp',
#  'Rainfall',
#  'Evaporation',
#  'Sunshine',
#  'WindGustSpeed',
#  'WindSpeed9am',
#  'WindSpeed3pm',
#  'Humidity9am',
#  'Humidity3pm',
#  'Pressure9am',
#  'Pressure3pm',
#  'Cloud9am',
#  'Cloud3pm',
#  'Temp9am',
#  'Temp3pm',
#  'Year',
#  'Month',
#  'Day']

# %% [markdown]
# # Engineering missing values in numerical variables

# %%
# check missing values in numerical variables in X_train
X_train[numerical].isnull().sum()
# Out:
# MinTemp            495
# MaxTemp            264
# Rainfall          1139
# Evaporation      48718
# Sunshine         54314
# WindGustSpeed     7367
# WindSpeed9am      1086
# WindSpeed3pm      2094
# Humidity9am       1449
# Humidity3pm       2890
# Pressure9am      11212
# Pressure3pm      11186
# Cloud9am         43137
# Cloud3pm         45768
# Temp9am            740
# Temp3pm           2171
# Year                 0
# Month                0
# Day                  0
# dtype: int64

# %%
# check missing values in numerical variables in X_test
X_test[numerical].isnull().sum()
# Out:
# MinTemp            142
# MaxTemp             58
# Rainfall           267
# Evaporation      12125
# Sunshine         13502
# WindGustSpeed     1903
# WindSpeed9am       262
# WindSpeed3pm       536
# Humidity9am        325
# Humidity3pm        720
# Pressure9am       2802
# Pressure3pm       2795
# Cloud9am         10520
# Cloud3pm         11326
# Temp9am            164
# Temp3pm            555
# Year                 0
# Month                0
# Day                  0
# dtype: int64

# %%
# print percentage of missing values in the numerical variables in training set
for col in numerical:
    if X_train[col].isnull().mean()>0:
        print(col, round(X_train[col].isnull().mean(),4))
# Out:
# MinTemp 0.0044
# MaxTemp 0.0023
# Rainfall 0.01
# Evaporation 0.4283
# Sunshine 0.4775
# WindGustSpeed 0.0648
# WindSpeed9am 0.0095
# WindSpeed3pm 0.0184
# Humidity9am 0.0127
# Humidity3pm 0.0254
# Pressure9am 0.0986
# Pressure3pm 0.0983
# Cloud9am 0.3792
# Cloud3pm 0.4023
# Temp9am 0.0065
# Temp3pm 0.0191

# %%
# impute missing values in X_train and X_test with respective column median in X_train
for df1 in [X_train, X_test]:
    for col in numerical:
        col_median=X_train[col].median()
        df1[col].fillna(col_median, inplace=True)

# %%
# check again missing values in numerical variables in X_train
X_train[numerical].isnull().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustSpeed    0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# Year             0
# Month            0
# Day              0
# dtype: int64

# %%
# check missing values in numerical variables in X_test
X_test[numerical].isnull().sum()
# Out:
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustSpeed    0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# Year             0
# Month            0
# Day              0
# dtype: int64

# %% [markdown]
# # Engineering missing values in categorical variables

# %%
# print percentage of missing values in the categorical variables in training set
X_train[categorical].isnull().mean()
# Out:
# Location       0.000000
# WindGustDir    0.065114
# WindDir9am     0.070134
# WindDir3pm     0.026443
# RainToday      0.010013
# dtype: float64

# %%
# print categorical variables with missing data
for col in categorical:
    if X_train[col].isnull().mean()>0:
        print(col, (X_train[col].isnull().mean()))
# Out:
# WindGustDir 0.06511419378659213
# WindDir9am 0.07013379749283542
# WindDir3pm 0.026443026179299188
# RainToday 0.01001283471350458

# %%
# impute missing categorical variables with most frequent value
for df2 in [X_train, X_test]:
    df2['WindGustDir'].fillna(X_train['WindGustDir'].mode()[0], inplace=True)
    df2['WindDir9am'].fillna(X_train['WindDir9am'].mode()[0], inplace=True)
    df2['WindDir3pm'].fillna(X_train['WindDir3pm'].mode()[0], inplace=True)
    df2['RainToday'].fillna(X_train['RainToday'].mode()[0], inplace=True)

# %%
# check missing values in categorical variables in X_train
X_train[categorical].isnull().sum()
# Out:
# Location       0
# WindGustDir    0
# WindDir9am     0
# WindDir3pm     0
# RainToday      0
# dtype: int64

# %%
# check missing values in categorical variables in X_test
X_test[categorical].isnull().sum()
# Out:
# Location       0
# WindGustDir    0
# WindDir9am     0
# WindDir3pm     0
# RainToday      0
# dtype: int64

# %%
# check missing values in X_train
X_train.isnull().sum()
# Out:
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# Year             0
# Month            0
# Day              0
# dtype: int64

# %%
# check missing values in X_test
X_test.isnull().sum()
# Out:
# Location         0
# MinTemp          0
# MaxTemp          0
# Rainfall         0
# Evaporation      0
# Sunshine         0
# WindGustDir      0
# WindGustSpeed    0
# WindDir9am       0
# WindDir3pm       0
# WindSpeed9am     0
# WindSpeed3pm     0
# Humidity9am      0
# Humidity3pm      0
# Pressure9am      0
# Pressure3pm      0
# Cloud9am         0
# Cloud3pm         0
# Temp9am          0
# Temp3pm          0
# RainToday        0
# Year             0
# Month            0
# Day              0
# dtype: int64

# %%
#Outliers-> caping

# %%
def max_value(df3, variable, top):
    return np.where(df3[variable]>top, top, df3[variable])
for df3 in [X_train, X_test]:
    df3['Rainfall']=max_value(df3, 'Rainfall', 3.2)
    df3['Evaporation']=max_value(df3, 'Evaporation', 21.8)
    df3['WindSpeed9am']=max_value(df3, 'WindSpeed9am', 55)
    df3['WindSpeed3pm']=max_value(df3, 'WindSpeed3pm', 57)

# %%
X_train.Rainfall.max(), X_test.Rainfall.max()
# Out:
# (3.2, 3.2)

# %%
X_train.Evaporation.max(), X_test.Evaporation.max()
# Out:
# (21.8, 21.8)

# %%
X_train.WindSpeed9am.max(), X_test.WindSpeed9am.max()
# Out:
# (55.0, 55.0)

# %%
X_train.WindSpeed3pm.max(), X_test.WindSpeed3pm.max()
# Out:
# (57.0, 57.0)

# %%
X_train[numerical].describe()
# Out:
#              MinTemp        MaxTemp       Rainfall    Evaporation  \
# count  113754.000000  113754.000000  113754.000000  113754.000000
# mean       12.193497      23.237216       0.675080       5.151606
# std         6.388279       7.094149       1.183837       2.823707
# min        -8.200000      -4.800000       0.000000       0.000000
# 25%         7.600000      18.000000       0.000000       4.000000
# 50%        12.000000      22.600000       0.000000       4.800000
# 75%        16.800000      28.200000       0.600000       5.400000
# max        33.900000      48.100000       3.200000      21.800000
#
#             Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  113754.000000  113754.000000  113754.000000  113754.000000
# mean        8.041154      39.884074      13.978155      18.614756
# std         2.769480      13.116959       8.806558       8.685862
# min         0.000000       6.000000       0.000000       0.000000
# 25%         8.200000      31.000000       7.000000      13.000000
# 50%         8.500000      39.000000      13.000000      19.000000
# 75%         8.700000      46.000000      19.000000      24.000000
# max        14.500000     135.000000      55.000000      57.000000
#
#          Humidity9am    Humidity3pm    Pressure9am    Pressure3pm  \
# count  113754.000000  113754.000000  113754.000000  113754.000000
# mean       68.867486      51.509547    1017.640649    1015.241101
# std        18.935587      20.530723       6.738680       6.675168
# min         0.000000       0.000000     980.500000     977.100000
# 25%        57.000000      37.000000    1013.500000    1011.000000
# 50%        70.000000      52.000000    1017.600000    1015.200000
# 75%        83.000000      65.000000    1021.800000    1019.400000
# max       100.000000     100.000000    1041.000000    1039.600000
#
#             Cloud9am       Cloud3pm        Temp9am        Temp3pm  \
# count  113754.000000  113754.000000  113754.000000  113754.000000
# mean        4.651801       4.703588      16.995062      21.688643
# std         2.292726       2.117847       6.463772       6.855649
# min         0.000000       0.000000      -7.200000      -5.400000
# 25%         3.000000       4.000000      12.300000      16.700000
# 50%         5.000000       5.000000      16.700000      21.100000
# 75%         6.000000       6.000000      21.500000      26.300000
# max         9.000000       8.000000      40.200000      46.700000
#
#                 Year          Month            Day
# count  113754.000000  113754.000000  113754.000000
# mean     2012.759727       6.404021      15.710419
# std         2.540419       3.427798       8.796821
# min      2007.000000       1.000000       1.000000
# 25%      2011.000000       3.000000       8.000000
# 50%      2013.000000       6.000000      16.000000
# 75%      2015.000000       9.000000      23.000000
# max      2017.000000      12.000000      31.000000

# %% [markdown]
# # Encode categorical variables

# %%
categorical
# Out:
# ['Location', 'WindGustDir', 'WindDir9am', 'WindDir3pm', 'RainToday']

# %%
X_train[categorical].head()
# Out:
#             Location WindGustDir WindDir9am WindDir3pm RainToday
# 110803   Witchcliffe           S        SSE          S        No
# 87289         Cairns         ENE        SSE         SE       Yes
# 134949  AliceSprings           E         NE          N        No
# 85553         Cairns         ESE        SSE          E        No
# 16110      Newcastle           W          N         SE        No

# %%
# encode RainToday variable
import category_encoders as ce
encoder = ce.BinaryEncoder(cols=['RainToday'])
X_train = encoder.fit_transform(X_train)
X_test = encoder.transform(X_test)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[107], line 2
#       1 # encode RainToday variable
# ----> 2 import category_encoders as ce
#       3 encoder = ce.BinaryEncoder(cols=['RainToday'])
#       4 X_train = encoder.fit_transform(X_train)
#
# ModuleNotFoundError: No module named 'category_encoders'

# %%
X_train=pd.concat([X_train[numerical],pd.get_dummies(X_train.RainToday),
                     pd.get_dummies(X_train.Location), 
                     pd.get_dummies(X_train.WindGustDir),
                     pd.get_dummies(X_train.WindDir9am),
                     pd.get_dummies(X_train.WindDir3pm)], axis=1)

# %%
X_train.head()
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 110803     13.9     22.6       0.2          4.8       8.5           41.0
# 87289      22.4     29.4       2.0          6.0       6.3           33.0
# 134949      9.7     36.2       0.0         11.4      12.3           31.0
# 85553      20.5     30.1       0.0          8.8      11.1           37.0
# 16110      16.8     29.2       0.0          4.8       8.5           39.0
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...    NNW  \
# 110803          20.0          28.0         65.0         55.0  ...  False
# 87289            7.0          19.0         71.0         59.0  ...  False
# 134949          15.0          11.0          6.0          2.0  ...  False
# 85553           22.0          19.0         59.0         53.0  ...  False
# 16110            0.0           7.0         72.0         53.0  ...  False
#
#            NW      S     SE    SSE    SSW     SW      W    WNW    WSW
# 110803  False   True  False  False  False  False  False  False  False
# 87289   False  False   True  False  False  False  False  False  False
# 134949  False  False  False  False  False  False  False  False  False
# 85553   False  False  False  False  False  False  False  False  False
# 16110   False  False   True  False  False  False  False  False  False
#
# [5 rows x 118 columns]

# %%
X_test=pd.concat([X_test[numerical],pd.get_dummies(X_test.RainToday),
                     pd.get_dummies(X_test.Location), 
                     pd.get_dummies(X_test.WindGustDir),
                     pd.get_dummies(X_test.WindDir9am),
                     pd.get_dummies(X_test.WindDir3pm)], axis=1)

# %%
X_test.head()
# Out:
#         MinTemp  MaxTemp  Rainfall  Evaporation  Sunshine  WindGustSpeed  \
# 86232      17.4     29.0       0.0          3.6      11.1           33.0
# 57576       6.8     14.4       0.8          0.8       8.5           46.0
# 124071     10.1     15.4       3.2          4.8       8.5           31.0
# 117955     14.4     33.4       0.0          8.0      11.6           41.0
# 133468      6.8     14.3       3.2          0.2       7.3           28.0
#
#         WindSpeed9am  WindSpeed3pm  Humidity9am  Humidity3pm  ...    NNW  \
# 86232           11.0          19.0         63.0         61.0  ...  False
# 57576           17.0          22.0         80.0         55.0  ...  False
# 124071          13.0           9.0         70.0         61.0  ...  False
# 117955           9.0          17.0         40.0         23.0  ...  False
# 133468          15.0          13.0         92.0         47.0  ...  False
#
#            NW      S     SE    SSE    SSW     SW      W    WNW    WSW
# 86232   False  False  False  False  False  False  False  False  False
# 57576   False   True  False  False  False  False  False  False  False
# 124071  False  False  False   True  False  False  False  False  False
# 117955  False  False  False  False  False   True  False  False  False
# 133468  False  False  False  False  False  False  False  False  False
#
# [5 rows x 118 columns]

# %% [markdown]
# # Feature Scaling

# %%
X_train.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall    Evaporation  \
# count  113754.000000  113754.000000  113754.000000  113754.000000
# mean       12.193497      23.237216       0.675080       5.151606
# std         6.388279       7.094149       1.183837       2.823707
# min        -8.200000      -4.800000       0.000000       0.000000
# 25%         7.600000      18.000000       0.000000       4.000000
# 50%        12.000000      22.600000       0.000000       4.800000
# 75%        16.800000      28.200000       0.600000       5.400000
# max        33.900000      48.100000       3.200000      21.800000
#
#             Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  113754.000000  113754.000000  113754.000000  113754.000000
# mean        8.041154      39.884074      13.978155      18.614756
# std         2.769480      13.116959       8.806558       8.685862
# min         0.000000       6.000000       0.000000       0.000000
# 25%         8.200000      31.000000       7.000000      13.000000
# 50%         8.500000      39.000000      13.000000      19.000000
# 75%         8.700000      46.000000      19.000000      24.000000
# max        14.500000     135.000000      55.000000      57.000000
#
#          Humidity9am    Humidity3pm    Pressure9am    Pressure3pm  \
# count  113754.000000  113754.000000  113754.000000  113754.000000
# mean       68.867486      51.509547    1017.640649    1015.241101
# std        18.935587      20.530723       6.738680       6.675168
# min         0.000000       0.000000     980.500000     977.100000
# 25%        57.000000      37.000000    1013.500000    1011.000000
# 50%        70.000000      52.000000    1017.600000    1015.200000
# 75%        83.000000      65.000000    1021.800000    1019.400000
# max       100.000000     100.000000    1041.000000    1039.600000
#
#             Cloud9am       Cloud3pm        Temp9am        Temp3pm  \
# count  113754.000000  113754.000000  113754.000000  113754.000000
# mean        4.651801       4.703588      16.995062      21.688643
# std         2.292726       2.117847       6.463772       6.855649
# min         0.000000       0.000000      -7.200000      -5.400000
# 25%         3.000000       4.000000      12.300000      16.700000
# 50%         5.000000       5.000000      16.700000      21.100000
# 75%         6.000000       6.000000      21.500000      26.300000
# max         9.000000       8.000000      40.200000      46.700000
#
#                 Year          Month            Day
# count  113754.000000  113754.000000  113754.000000
# mean     2012.759727       6.404021      15.710419
# std         2.540419       3.427798       8.796821
# min      2007.000000       1.000000       1.000000
# 25%      2011.000000       3.000000       8.000000
# 50%      2013.000000       6.000000      16.000000
# 75%      2015.000000       9.000000      23.000000
# max      2017.000000      12.000000      31.000000

# %%
cols=X_train.columns

# %%
from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler()
X_train=scaler.fit_transform(X_train)
X_test=scaler.transform(X_test)

# %%
X_train=pd.DataFrame(X_train, columns=[cols])
X_test=pd.DataFrame(X_test, columns=[cols])

# %%
X_train.describe()
# Out:
#              MinTemp        MaxTemp       Rainfall    Evaporation  \
# count  113754.000000  113754.000000  113754.000000  113754.000000
# mean        0.484406       0.530004       0.210962       0.236312
# std         0.151741       0.134105       0.369949       0.129528
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.375297       0.431002       0.000000       0.183486
# 50%         0.479810       0.517958       0.000000       0.220183
# 75%         0.593824       0.623819       0.187500       0.247706
# max         1.000000       1.000000       1.000000       1.000000
#
#             Sunshine  WindGustSpeed   WindSpeed9am   WindSpeed3pm  \
# count  113754.000000  113754.000000  113754.000000  113754.000000
# mean        0.554562       0.262667       0.254148       0.326575
# std         0.190999       0.101682       0.160119       0.152384
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.565517       0.193798       0.127273       0.228070
# 50%         0.586207       0.255814       0.236364       0.333333
# 75%         0.600000       0.310078       0.345455       0.421053
# max         1.000000       1.000000       1.000000       1.000000
#
#          Humidity9am    Humidity3pm  ...            NNW             NW  \
# count  113754.000000  113754.000000  ...  113754.000000  113754.000000
# mean        0.688675       0.515095  ...       0.054530       0.060288
# std         0.189356       0.205307  ...       0.227061       0.238021
# min         0.000000       0.000000  ...       0.000000       0.000000
# 25%         0.570000       0.370000  ...       0.000000       0.000000
# 50%         0.700000       0.520000  ...       0.000000       0.000000
# 75%         0.830000       0.650000  ...       0.000000       0.000000
# max         1.000000       1.000000  ...       1.000000       1.000000
#
#                    S             SE            SSE            SSW  \
# count  113754.000000  113754.000000  113754.000000  113754.000000
# mean        0.067259       0.101605       0.064059       0.056402
# std         0.250471       0.302130       0.244860       0.230698
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#                   SW              W            WNW            WSW
# count  113754.000000  113754.000000  113754.000000  113754.000000
# mean        0.064464       0.069334       0.060798       0.065483
# std         0.245578       0.254022       0.238960       0.247378
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
# [8 rows x 118 columns]

# %% [markdown]
# # Model training

# %%
# train a logistic regression model on the training set
from sklearn.linear_model import LogisticRegression
# instantiate the model
logreg=LogisticRegression(solver='liblinear', random_state=0)
# fit the model
logreg.fit(X_train, y_train)
# Out:
# LogisticRegression(random_state=0, solver='liblinear')

# %% [markdown]
# # Predict results

# %%
y_pred_test=logreg.predict(X_test)
y_pred_test
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'Yes'], dtype=object)

# %%
# probability of getting output as 0 - no rain
logreg.predict_proba(X_test)[:,0]
# Out:
# array([0.91388015, 0.83563461, 0.82035835, ..., 0.97675231, 0.798564  ,
#        0.30735417])

# %%
# probability of getting output as 1 - rain
logreg.predict_proba(X_test)[:,1]
# Out:
# array([0.08611985, 0.16436539, 0.17964165, ..., 0.02324769, 0.201436  ,
#        0.69264583])

# %% [markdown]
# # Check accuracy score

# %%
from sklearn.metrics import accuracy_score
print('Model accuracy score: {}'. format(accuracy_score(y_test, y_pred_test)))
# Out:
# Model accuracy score: 0.850170540455009

# %%
#Compare the train-set and test-set accuracy

# %%
y_pred_train=logreg.predict(X_train)
y_pred_train
# Out:
# array(['No', 'No', 'No', ..., 'No', 'No', 'No'], dtype=object)

# %%
print('Training-set accuracy score: {}'. format(accuracy_score(y_train, y_pred_train)))
# Out:
# Training-set accuracy score: 0.8476449179809061

# %%
#Check for overfitting and underfitting

# %%
# print the scores on training and test set
print('Training set score: {}'.format(logreg.score(X_train, y_train)))
print('Test set score: {}'.format(logreg.score(X_test, y_test)))
# Out:
# Training set score: 0.8476449179809061
# Test set score: 0.850170540455009

# %%
# fit the Logsitic Regression model with C=100
logreg100=LogisticRegression(C=100, solver='liblinear', random_state=0)
logreg100.fit(X_train, y_train)
# Out:
# LogisticRegression(C=100, random_state=0, solver='liblinear')

# %%
# print the scores on training and test set
print('Training set score: {}'.format(logreg100.score(X_train, y_train)))
print('Test set score: {}'.format(logreg100.score(X_test, y_test)))
# Out:
# Training set score: 0.8477591996764949
# Test set score: 0.8505221702591511

# %%
# fit the Logsitic Regression model with C=001
logreg001=LogisticRegression(C=0.01, solver='liblinear', random_state=0)
logreg001.fit(X_train, y_train)
# Out:
# LogisticRegression(C=0.01, random_state=0, solver='liblinear')

# %%
print('Training set score: {}'.format(logreg001.score(X_train, y_train)))
print('Test set score: {}'.format(logreg001.score(X_test, y_test)))
# Out:
# Training set score: 0.8408583434428679
# Test set score: 0.8448257674320475

# %%
#Compare model accuracy with null accuracy

# %%
# check class distribution in test set
y_test.value_counts()
# Out:
# RainTomorrow
# No     22067
# Yes     6372
# Name: count, dtype: int64

# %%
# check null accuracy score
null_accuracy=(22067/(22067+6372))
print('Null accuracy score: {}'. format(null_accuracy))
# Out:
# Null accuracy score: 0.7759414888005908

# %% [markdown]
# # Confusion matrix

# %%
# Print the Confusion Matrix and slice it into four pieces
from sklearn.metrics import confusion_matrix,ConfusionMatrixDisplay
cm=confusion_matrix(y_test, y_pred_test)
cm
# Out:
# array([[20892,  1175],
#        [ 3086,  3286]], dtype=int64)

# %%
disp=ConfusionMatrixDisplay(confusion_matrix=cm, display_labels=logreg.classes_)
disp.plot()

# %% [markdown]
# # Classification metrices

# %%
from sklearn.metrics import classification_report
print(classification_report(y_test, y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#           No       0.87      0.95      0.91     22067
#          Yes       0.74      0.52      0.61      6372
#
#     accuracy                           0.85     28439
#    macro avg       0.80      0.73      0.76     28439
# weighted avg       0.84      0.85      0.84     28439

# %% [markdown]
# # Classification accuracy

# %%
TP=cm[0,0]
TN=cm[1,1]
FP=cm[0,1]
FN=cm[1,0]

# %%
# print classification accuracy
classification_accuracy=(TP+TN)/float(TP+TN+FP+FN)
print('Classification accuracy : {}'.format(classification_accuracy))
# Out:
# Classification accuracy : 0.850170540455009

# %% [markdown]
# # Classification error

# %%
classification_error=(FP+FN)/float(TP+TN+FP+FN)
print('Classification error : {}'.format(classification_error))
# Out:
# Classification error : 0.14982945954499102

# %% [markdown]
# # Precision

# %%
# print precision score
precision=TP/float(TP+FP)
print('Precision : {}'.format(precision))
# Out:
# Precision : 0.9467530701953143

# %% [markdown]
# # Recall

# %%
recall=TP/float(TP+FN)
print('Recall or Sensitivity : {}'.format(recall))
# Out:
# Recall or Sensitivity : 0.8712986904662607

# %% [markdown]
# # True Positive Rate

# %%
true_positive_rate=TP/float(TP+FN)
print('True Positive Rate : {}'.format(true_positive_rate))
# Out:
# True Positive Rate : 0.8712986904662607

# %% [markdown]
# # False Positive Rate

# %%
false_positive_rate=FP/float(FP+TN)
print('False Positive Rate : {}'.format(false_positive_rate))
# Out:
# False Positive Rate : 0.26339385787939923

# %% [markdown]
# # Specificity(True Negative Rate)

# %%
specificity=TN/(TN+FP)
print('Specificity : {}'.format(specificity))
# Out:
# Specificity : 0.7366061421206007

# %% [markdown]
# # Adjusting the threshold level

# %%
# print the first 10 predicted probabilities of two classes- 0 and 1
y_pred_prob=logreg.predict_proba(X_test)[0:10]
y_pred_prob
# Out:
# array([[0.91388015, 0.08611985],
#        [0.83563461, 0.16436539],
#        [0.82035835, 0.17964165],
#        [0.99025727, 0.00974273],
#        [0.95727646, 0.04272354],
#        [0.97992445, 0.02007555],
#        [0.17844363, 0.82155637],
#        [0.23482362, 0.76517638],
#        [0.9005317 , 0.0994683 ],
#        [0.85483248, 0.14516752]])

# %%
# store the probabilities in dataframe
y_pred_prob_df=pd.DataFrame(data=y_pred_prob, columns=['Prob of - No rain tomorrow (0)', 'Prob of - Rain tomorrow (1)'])
y_pred_prob_df
# Out:
#    Prob of - No rain tomorrow (0)  Prob of - Rain tomorrow (1)
# 0                        0.913880                     0.086120
# 1                        0.835635                     0.164365
# 2                        0.820358                     0.179642
# 3                        0.990257                     0.009743
# 4                        0.957276                     0.042724
# 5                        0.979924                     0.020076
# 6                        0.178444                     0.821556
# 7                        0.234824                     0.765176
# 8                        0.900532                     0.099468
# 9                        0.854832                     0.145168

# %%
# print the first 10 predicted probabilities for class 1 - Probability of rain
logreg.predict_proba(X_test)[0:10, 1]
# Out:
# array([0.08611985, 0.16436539, 0.17964165, 0.00974273, 0.04272354,
#        0.02007555, 0.82155637, 0.76517638, 0.0994683 , 0.14516752])

# %%
# store the predicted probabilities for class 1 - Probability of rain
y_pred1=logreg.predict_proba(X_test)[:, 1]

# %%
# plot histogram of predicted probabilities
plt.rcParams['font.size']=12
plt.hist(y_pred1, bins=10)
plt.title('Histogram of predicted probabilities of rain')
plt.xlim(0,1)
plt.xlabel('Predicted probabilities of rain')
plt.ylabel('Frequency')
# Out:
# Text(0, 0.5, 'Frequency')
